# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
#  # Install dependencies and libraries

# %%
# Install dependencies
# !pip install lief==0.12.0
# !pip install deap
# !pip install tqdm
# !pip install python-magic

# Install ML-Pentest Lib
# !pip install ml-pentest

# Install EMBER augmented version
# !pip install ember-mivia
# Out:
# Collecting lief==0.12.0
#   Downloading lief-0.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 13.3 MB/s eta 0:00:00
# Installing collected packages: lief
# Successfully installed lief-0.12.0
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.25.2)
# Installing collected packages: deap
# Successfully installed deap-1.4.1
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Installing collected packages: python-magic
# Successfully installed python-magic-0.4.27
# Collecting ml-pentest
#   Downloading ml_pentest-0.0.1.tar.gz (57.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 MB 9.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: ml-pentest
#   Building wheel for ml-pentest (pyproject.toml) ... done
#   Created wheel for ml-pentest: filename=ml_pentest-0.0.1-py3-none-any.whl size=57887807 sha256=be0d3da1439b3a8316ebd21ba132186b06b41b714da495e81333ac21a42c2022
#   Stored in directory: /root/.cache/pip/wheels/ed/f4/4c/23846e544e3da15cc0a566ea450040ce9181b7d210ef2e41a3
# Successfully built ml-pentest
# Installing collected packages: ml-pentest
# Successfully installed ml-pentest-0.0.1
# Collecting ember-mivia
#   Downloading ember-mivia-0.0.6.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ember-mivia
#   Building wheel for ember-mivia (setup.py) ... done
#   Created wheel for ember-mivia: filename=ember_mivia-0.0.6-py3-none-any.whl size=13991 sha256=a8d2e009d58ad8879534b5f9eceb7c8b253ba2d2b7dff8533dc24e5bd0153201
#   Stored in directory: /root/.cache/pip/wheels/0e/88/68/7b91124461cd44092bd93e61e429cf81210938731268a65c54
# Successfully built ember-mivia
# Installing collected packages: ember-mivia
# Successfully installed ember-mivia-0.0.6

# %% [markdown]
# # Import and model definition

# %%
from ml_pentest.attacks.blackbox.genetic_attack.GAMMA.gamma_section_injection import GammaSectionInjection
from ml_pentest.attacks.blackbox.genetic_attack.GAMMA.attack_utils import create_section_population_from_folder

import os
import torch
import lief
import numpy as np
import random

# %% [markdown]
# ## Defining custom Wrapper

# %%
from ml_pentest.models.wrappers.model_wrapper import ModelWrapper
from ml_pentest.models.feature_extractor.pe_format.ember_feature_extractor import get_ember_features_from_bytes

def remove_features(features):
  features_filtered = features[:626] + features[637:647] + features[657:]

  return features_filtered

class MyWrapper(ModelWrapper):
    """
    GBDTWrapper is a concrete implementation of the ModelWrapper abstract class, specifically designed for Gradient Boosting Decision Tree (GBDT) models.

    Methods:
        __init__(model: object) -> None:
            Initializes a GBDTWrapper object.
        classify_sample(sample: bytes) -> float:
            Classifies a single sample using the GBDT model and returns the classification probability.

    Note:
        This class assumes that the GBDT model object passed to it has a method called 'predict' for making predictions.
    """
    def __init__(self, model):
        """
        Initializes a GBDTWrapper object.

        Args:
            model (object): An object that represents the GBDT classifier model to be used for classification.
        """
        super().__init__(model)

    def classify_sample(self, sample):
        """
        Classifies a single sample using the GBDT model.
        This method includes all necessary pre-processing steps to prepare the sample for the model and returns the classification probability.

        Args:
            sample (bytes): A byte array that represents an executable file.

        Returns:
            float: The classification probability, ranging from 0 to 1, where 1 represents the malware class.
        """
        ember_features = get_ember_features_from_bytes(sample)
        ember_features = remove_features(ember_features)
        features = np.array([ember_features])
        result = self._model.predict_proba(features)

        return result[0][1].item()

# %% [markdown]
# Loading model and instanciating wrapper:

# %%
import gdown

id = '1u4AhwQgwNk-0F7GONRL2LXdrDiFz3Ao2'
gdown.download(id=id, output="voting_classifier.pkl")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1u4AhwQgwNk-0F7GONRL2LXdrDiFz3Ao2
# To: /content/voting_classifier.pkl
# 100%|██████████| 10.9M/10.9M [00:00<00:00, 23.2MB/s]
# 'voting_classifier.pkl'

# %%
import pickle

model_path = "voting_classifier.pkl"

my_model = None
with open(model_path, 'rb') as file:
    my_model = pickle.load(file)

model_wrapper = MyWrapper(my_model)

# %% [markdown]
# # Load the data

# %% [markdown]
# ## Sorel-20M test set malware

# %% [markdown]
# Loading test sets raw malware:

# %%
url = '1-CNx_k1yEJ-RDC94nXUMlhtc1FQH7lzt'
gdown.download(id=url, output="test_set.tar.gz")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-CNx_k1yEJ-RDC94nXUMlhtc1FQH7lzt
# From (redirected): https://drive.google.com/uc?id=1-CNx_k1yEJ-RDC94nXUMlhtc1FQH7lzt&confirm=t&uuid=6ece22d0-7e81-4016-96ee-16286170cb07
# To: /content/test_set.tar.gz
# 100%|██████████| 2.52G/2.52G [00:47<00:00, 53.1MB/s]
# 'test_set.tar.gz'

# %%
# !mkdir -p test
# !tar -zxf 'test_set.tar.gz' -C /content/test

# %% [markdown]
# ## RUN THIS SECTION ONLY THE FIRST TIME
# ## Load the initial input sample that we want to obfuscate

# %%
malware_directory = '/content/malware'

malwares = dict()
max_num_samples = 100
while len(malwares) < max_num_samples:
  classification_results = 0
  # search for a file classified as malware (with classification result > 0.5)
  while classification_results < 0.5:
    # input sample that we want to obfuscate
    malware_name = random.choice(os.listdir(malware_directory))
    path = os.path.join(malware_directory, malware_name)

    with open(path, "rb") as file_handle:
      code = file_handle.read()
      try:
        classification_results = model_wrapper.classify_sample(code)
        if classification_results >= 0.5:
          print(f"Malware correctly classified:\n\t{malware_name}")
          print("Number of malwares added:", len(malwares))
          x = np.frombuffer(code, dtype=np.uint8)
          malwares[malware_name] = x
      except Exception:
        continue

# %%
print("Number of malwares in dictionary (expected 100):", len(malwares))

# %% [markdown]
# Saving malwares in a folder for future access:

# %%
import os
import shutil
malware_path = "/content/malware"
destination_path = "path/to/save/folder"

for malware_name in malwares.keys():
  print(f"Moving {malware_name} to folder.")
  shutil.copy(f"{malware_path}/{malware_name}", destination_path)

# %%
# !zip -r 'path/to/save/malware_to_obfuscate.zip' destination_path

# %% [markdown]
# Check that all files are classified as malware:

# %%
incorrect_samples = 0
destination_path = "path/to/save/folder"
malware_directory = "/content/test/malware"

for malware_name in os.listdir(destination_path):
  path = os.path.join(malware_directory, malware_name)

  with open(path, "rb") as file_handle:
    code = file_handle.read()
    try:
      classification_results = model_wrapper.classify_sample(code)

      if classification_results < 0.5:
        print(f"Incorrect classification, model classified {malware_name} sample as benign with a probability of {classification_results}")
        incorrect_samples += 1
      else:
        print(f"{malware_name} classified as malware correctly")
    except:
      print("Exception during the analysis")

print(f"Number of incorrect classification (expected 0): {incorrect_samples}")

# %% [markdown]
# # Gamma Attack

# %% [markdown]
# ## Extract the benign section to inject

# %%
id = '1DRH8KDmf-oTm6Xd7rYcbKFeGXBQrgRpS'

gdown.download(id=id, output ='malware_to_obfuscate.zip')

# !unzip malware_to_obfuscate.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1DRH8KDmf-oTm6Xd7rYcbKFeGXBQrgRpS
# From (redirected): https://drive.google.com/uc?id=1DRH8KDmf-oTm6Xd7rYcbKFeGXBQrgRpS&confirm=t&uuid=5b0eb8bc-ce34-457f-8c99-e19a9fdba8fa
# To: /content/malware_to_obfuscate.zip
# 100%|██████████| 112M/112M [00:04<00:00, 24.0MB/s]
# Archive:  malware_to_obfuscate.zip
#    creating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/14649a48ea276bfbb2e5c9ce912c3e232483c582d884e175ce7bf8b8337d48f9
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2d9294da989eef84609a549bcc41a6efe135a90da2b4a95c3d9b2adafa02d813
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/493f031eba201838fa24a184e93125dd1409987e4859cbbc066b2ce9b2cafde7
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/b889e0e8212eb10c6debfed2c47a37984eab990658c082b17c1a88680ba10507
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/0926c24a0653319193377d6e742a3d25fd5b91d24578a999962262502b6cc974
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/3c2b3d01388be86ec88f262e7dfb53079eb12109bd74facf0eeb08d6e6712ec7
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/1a74e97e55d230e50694b9bbb563c17b75bfe0520a9edd31e580ec6522acc716
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7550c63fd29f6a3751ec0da1d4c240f986edb345799e54a48dbf28f3be0b9434
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/65206af32f225648faad241bd68f4d9e183ccbbcdbb191d17bb5a9f24e26d3fb
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/bae59383801587f97e2eb7ecacf977054a2d662b28e67279ae0082ae3a9a8b24
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/076fc32a45da40441c2a929132ac2d355c500e27d891cedade61bae88838ade5
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/17321569c24141ea4995c8ebca2123d5a40357f9cdcbcaf794d0ee12cf45cfae
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/f3e79c652bf5dc691dbeaa633492d2d311e22cd6d7ef39944a0c98dec9140800
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/13f83abc9978e17f744d2897d9d68caf64b98189bdba24a4ef25456d5e09f2ea
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/f60b7e6a167f95877a9a350e3d19ed1dba91a79465ff755bb59891cc21c803d1
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/96470b3c5f5ddb28adb2e642f173d68a52c64ad0b53b7540ba2312da24a976e2
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7ca225cb352f82b636d7006b5590773cdb8b2fa6807e1bac2f37e8d9991137b1
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/91909d7421d5bf4690223a78d554dbee00cd1b09508cc64bae858199a2406218
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7e0714ace2ea57d70170dd6a1ccfb471790980b9f2a06290f6eb11fd23ba0fa0
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c6efbf57142930d5038005df371d233821f2ef4704d3d9a176b43b8eea692495
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/290104483b6b979e0637dfd0ffe6a2c6e9a867626eb78ecda7ffee327009658a
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/50a2f4d6f2270c985b93e6497db9f7c3b80e884d3f530f26295440b91cff72e9
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/965167e8e4bd210d1350f207e577e6d77519e965e5b37fccee90dba7433db1e3
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/421f65c973cf5523473b0730cd37e60d8375c63e0f7bb9f416253b652ef0e677
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7cc1e6c89bee35ba9c8a318e2d4b79d3b8c38a4927d4037c2be183e3effd54e2
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/32d774e2b048c2c068ca3bcbb9becccfa65fde0805addc212b7b211c9e5345dd
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/1700262413b7bdbb0729b77dd3d5bbabaec0ab45b0cda643cb279b5a440a8886
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/82b8d2771ee125bc0ae7b565703d2c508da32c40cfc01adb9530a8fb9af56cab
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c86c383aae69c393c05cea3ed27b8a7e5ab2cd3365aab4443cb01fcab35f3f88
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7e2f76f4d3e9f45e02c6e860f6dffaa231334ee6bfaaf580a724c06019379fa6
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/46806e9dcae686f0c061de42ba2fc168cba2803591af42e1cbd724a055227083
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/6b06ae3aeda24d108211be382bd5b5b711e83f9a88df4d5d28c06c68fab3a0bd
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/68eec596f2729165e62b2268a78a13d0cd9b20a646d6ced4a3744c95bd709c4f
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c3aa7ab9fb2cf0571fe71c99c39cb7d001b086ac3ffae7a94f27fa59f654d7ee
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/95b5220bed52ee26acffe451ad75903394f3ed424555ebc7dc9e14793efc12f6
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2531787eac6b5548c7b935ad75d8abaae93487b618564963c29ebc1d1d9982d8
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/a97d0574286c7bccaa1f5d57ddc7ac186001d10a431059d761d6680ac0976b63
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/28626213fd55af3a33f82ad656d720968d14b049214593ff83afa86900b9e008
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/81232fb4a778160be65253f74a3c59ae391f3d98f8a3d6430017caee2bf9a385
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/83b73a2e58e90df167423d1fe2927a664d46da4527cbacefcc7c9cee29a19242
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/5fd41dbfb279c04aa27eea20d870cae3161c50bb20bc5246a8b264fc9be1d9d1
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/5621ed3b22b2d56cd79ba32c6d0ef73461a5b96f3d392357183a8175aaeed2aa
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/063ed97f6c7e3f60e6a40fe2b20254b816886329040bb591c8629ca19a83c4a2
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/1ffc08073bbc80cc481c8a277cb2ad60f9be6d1b36e4776faeb3df28398d9807
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/724d8b6d2607e4b603ca76b0ae36e62d01d906761b618902b0b8e8697cfad78d
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/614d7d04eae02ee254cffc87e114640c61ff842f728bd4eb6ae5f0180cc9d0c3
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/4bebb0b8bc2b2087e12b79f8a7592786283b9cc560746061c156b70fc2973afe
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/f20201afb2e601c968e533a6d9dac0dfd09ba58b9ab47e5233e3b2748abb9e58
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7721d43f40f40dcda12f7a60000984b4968fb289e37259fbd3d49dee9bcf653b
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/49f1cee1e788ab9df91a74cea9f79ff55963b799dc846df57dfea2d37d934e71
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/4f9176117c322cf5ba962753e2826e1bb808cd880dd2819f91a53a03b3695ab2
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/21ffad863d2702018571526b280f28fe362a271687d890b75975219a8005bd72
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/4217571fee650f21c53fe125cacbc6d5d036071efef302f247ca73f9083ded11
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/d0e73c4be2ebdc0ca0284955091b1e733b5ac908dcf916bc22e86857c29081f4
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/e6cf151cdc2ea52f92d81591572f2e74586248f64b069276cd3ae039e5a937e9
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/552e418bcc93c9f47e5120061981ac6c0a7a631bbb9c14c86230c3e810ba93ac
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/e905d382a82080ffcbc5bcb645a73262b9a92a0aee158b7aba9f2b39ce6b31ec
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/284a93d6839a4feee1edd473a1b690c08bf623d833810f4736ff0a3bcc9c6d7e
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/152a208fb6388af62a4f38623990442a19a8868ec1d57121f046e55c580e7e35
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/3d4615701b6e65bd396a771c62bf23f2e7854b774fed35d273cb5b5da94bc833
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c41f081c16cc8d1130da60007de13bf3be3947c88d91322743388794e6fca865
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2abbccd3a587e04aea74b45697ca4feb61f52f10a20ce8da6691827d9f96dab6
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/8cd1b3be49906efcbeb04ebd604d2678fa8a01a2b036317f3e39a944518a8ff3
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/964f9e6c5112062a20498a95793e6fe0cc103c36a89920f0634661067d3f96bb
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c9c0320d608a532e94c15f7475b532a3a2f2f52c5530a690d839636b6d2ba106
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/d4ec2ce32d1a263d7188c093bdb0280d7583398909b53a4dfa1a50f30ce542fc
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/f051e85df33ad9a9b0f9f3ad6b190b483f717a6ed3eb7c6a4a94a230e4d7f22c
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/be95a5e4c85a04c30e4fb97e99d4f2b4bb32180a966ece63a505db0044ce818c
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/22305707713b87b329545fad6465226f4606a2fe68665f6876e99a08f801a256
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/596dd7a618a759d376dd85df74c08d0c2688bf06d799664f75c282187d6555f9
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2a4f1807ba27c7391bcbb45dff179e3ea246140e832b5a0a22e70f807d6358ce
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/07ebf66006e5c7706dc973b3997a8d7b6dc40ec536fd59b92e675f270d35d29d
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2391960177541d00cfcb6ae627a72d4c09cbc4a291a2c35b89dd866174d70907
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/429088920b8f137b8ea87086c27b648b9db069c3db3c400e17d0628e89b7b601
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/02c200fa70b5ed36146a6f1036df0193200773c7d0de82c6d1c0f182f12b3f7e
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c7d2da651e24db5780b592de96d220bfa003da829ef3ab0a5489840b47131bd3
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/7feaa52560c5b8599bf9d3c4bd58bfe2eaf1029262fff98cbb3b308b6901c8ca
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/323f124cb7f082dd1e036385294ac9e0e93146f670fd063486e39cab35bf4367
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/57411c15e360602bbc4b58688fac0870c9fa640d81b176e3de155f34a025aded
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/c0a344e3912f1aa571abb7010296082abe4ff5515e38e6a9e189e9fb8a565888
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/065eaa1d7c4af131e7a75313b08367b555fe3e97ecc132699aa97996ea1e23f0
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/20968ec387d41ba52846cb91ccb0e888b45ce211e5a4a9eee427ab784a2ba69e
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/e0a72656d92545417a5cd59a9687b5536715aace7a6a21fd06e20453d3db5c8a
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/1da1677a4285187378b3c1843eeb2ec7260f7206259431ca8e2bb461403c9b2d
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/ec29775aaaa21b17fc7ad935e6ee5fb7c01e2ab3547dab28e5e6b4833d070808
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/5633f5c8048af2174ef565cb901c63592708feabf00b175f49474544406923f0
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/9341bad6e5d535db1ba740453cb586e4d58e9b1b6d5e4ab48327fcef86450416
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/0681caae487188291b3ac748966425d8e7dd3ae059f33e35b656d401a56f43ab
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/2b03c13f1b854af80ac0d80674b8c1f3733032176cea7b32ae2fde5b2c2bedca
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/6972e4dabac819c96bd3e3ae0c872f397949dc91555c2cc66de55eff1bca72e4
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/af3371a52f542ab1855b454143a72de0ecd907780e65a6bcdf9a4e220493f311
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/b23007d36b12107b1c807fb0791545330c7525f662ebfa3a771822fa14036787
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/ed60f63ca088f65329f8f64411ed5a9dacd5914be1db98caa19a14756e7f3e52
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/3d6af51a41973a7c9b1f48f2dc62d29270ad1949fc89ccdd0a5c0c484da14ebe
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/02a30e760da6f274168ef0213b92ac9757eb948ea2e544f491aaa309ec553570
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/a359c0c5e176054620d6ee0b3d31d8c84194ba46d190b415cb87bb77afcde4d7
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/19159a59d6ef1757cb8c3343fca275e2e20ebbb0d597f539dde7691fcf31babb
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/ce26aea7647a6c1489d4453be17f7adbe3455d9af14fa9232efc8be0c515e074
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/341c307253094617c67236c2e7d0701c3197345dfd9d035f0c9826839014a633
#   inflating: content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate/793f0db45a72e264f47ed4564ca9b7e71f16a944409104d3898bfd0f53485c43

# %%
benign_path = '/content/test/benign'
malware_path = '/content/content/drive/Shareddrives/AFC/gamma_handcrafted/malwares_to_obfuscate'

section_population_25, _ = create_section_population_from_folder(
    benign_path, how_many = 25, sections_to_extract=['.data','.rdata', '.idata', '.rodata'],
    cache_file='/content/section_population.pkl')

# Section population with how_many = 50
section_population_50, _ = create_section_population_from_folder(
    benign_path, how_many = 50, sections_to_extract=['.data','.rdata', '.idata', '.rodata'],
    cache_file='/content/section_population.pkl')
print("Section extracted")

# Attack parameters
lambda_values = [10e-3, 10e-5, 10e-7, 10e-9]
query_values = [20, 60, 120, 300]
POPULATION_SIZE = 20
# Out:
# Section extracted

# %% [markdown]
# ## Create the attack

# %%
from ml_pentest.attacks.blackbox.genetic_attack.GAMMA.attack_utils import generate_adv_samples_from_folder

def gamma_attack(base_path, section_population):

  if not os.path.exists(os.path.join(base_path, 'samples')):
      os.makedirs(os.path.join(base_path, 'samples'))
  if not os.path.exists(os.path.join(base_path, 'results')):
      os.makedirs(os.path.join(base_path, 'results'))

  for lambda_value in lambda_values:
      if not os.path.isdir(os.path.join(base_path, 'samples',str(lambda_value))):
          os.mkdir(os.path.join(base_path, 'samples',str(lambda_value)))
      for query_budget in query_values:
          destination_folder = os.path.join(base_path, 'samples', str(lambda_value),str(query_budget))
          if not os.path.isdir(destination_folder):
              os.mkdir(destination_folder)

          print(destination_folder, base_path)
          print("Lambda: ", lambda_value, "Query budget: ", query_budget)
          attack = GammaSectionInjection(section_population=section_population, model_wrapper=model_wrapper,
                                      population_size=POPULATION_SIZE, lambda_value=lambda_value, iterations=100,
                                      debug=False, hard_label=False, query_budget=query_budget,
                                      stagnation=5)
          result_file = os.path.join(base_path, 'results', 'results_'+str(lambda_value)+'_'+str(query_budget)+'.json')
          generate_adv_samples_from_folder(source_folder=malware_path,
                                        destination_folder=destination_folder, gamma_attack=attack, model=model_wrapper,result_file=result_file)

# %%
#GAMMA attack with how_many = 25
gamma_attack('/content/attack_results_25', section_population_25)

#GAMMA attack with how_many = 50
gamma_attack('/content/attack_results_50', section_population_50)

# %% [markdown]
# ## Evaluate the attack

# %%
base_path = '/content/attack_results_25/results'
variant_path = '/content/attack_results_50/results'

models = dict()
models["how_many = 25"] = base_path
models["how_many = 50"] = variant_path

# %%
from ml_pentest.attack_reports.blackbox.genetic_attack.GAMMA.analize_results import compute_mean_times, print_gamma_results, plot_detection_rate, plot_injected_bytes, plot_heatmap, plot_detection_rate_vs_query_budget, plot_avg_injected_bytes_vs_query_budget, plot_gamma_attack
import os
import numpy as np

malware_files = os.listdir(malware_path)
class_results = []

for f in malware_files:
    with open(os.path.join(malware_path, f), 'rb') as file:
        file_bytes = file.read()
        class_results.append( model_wrapper.classify_sample(file_bytes) )

avg_detection_rate = np.mean(class_results)

model_name='MalConv2'

print("============================ GAMMA Results ============================")

print("===== how_many = 25 =====")
for lambda_value in lambda_values:
    print_gamma_results(base_path, lambda_value, query_values, avg_detection_rate = avg_detection_rate)

print("===== how_many = 50 =====")
for lambda_value in lambda_values:
    print_gamma_results(variant_path, lambda_value, query_values, avg_detection_rate = avg_detection_rate)


save_path = '/content/attack_results/plots'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Plotting graphs for how_many = 25
plot_detection_rate(base_path, os.path.join(base_path, '25'), query_values, lambda_values, 'detection_rate_gamma.png', model_name=model_name)
plot_injected_bytes(base_path, os.path.join(base_path, '25'), query_values, lambda_values, 'GAMMA', 'gamma_injected_bytes.png', model_name=model_name,  x_range_kb=None)
plot_heatmap(base_path, os.path.join(base_path, '25'), query_values, lambda_values, 'heatmap.png')

# Plotting graphs for how_many = 50
plot_detection_rate(base_path, os.path.join(base_path, '50'), query_values, lambda_values, 'detection_rate_gamma.png', model_name=model_name)
plot_injected_bytes(base_path, os.path.join(base_path, '50'), query_values, lambda_values, 'GAMMA', 'gamma_injected_bytes.png', model_name=model_name,  x_range_kb=None)
plot_heatmap(base_path, os.path.join(base_path, '50'), query_values, lambda_values, 'heatmap.png')

# Plotting graphs to compare two attacks
plot_gamma_attack(base_path, variant_path, save_path, query_values, lambda_values, 'gamma_attack.png', model_name=model_name)
plot_detection_rate_vs_query_budget(models, query_values, lambda_values, save_path, 'detection_vs_query.png')
plot_avg_injected_bytes_vs_query_budget(models, query_values, lambda_values, save_path, file_name='avg_injected_bytes_vs_query_budget.png', lower_limit=None, upper_limit=None)
